# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# %%writefile 1_1.txt
# "Hey, my name is Shubham, I am a Data Scientist working for Pfizer. I am proficient in Advanced Python, Advanced R, Advanced EXCEL and Advanced SQL. I am also an expert in Machine Learning Algorithms, Natural Language Processing, Deep Learning, and Big Data. I am also proficient in Amazon AWS and data Visualisation Techniques like Power BI and Tableau. I am an asset to my organisation. I am also an expert in modelling complex optimization problems and have a strong hold in the Operations Reserach Domain."
# Out:
# Overwriting 1_1.txt

# %%
doc= nlp(open(r"1_1.txt",'r').read())

# %%
doc[7]
# Out:
# ,

# %%
doc[8]
# Out:
# I

# %%
for token in doc:
    print(token.text, ">>>" ,token.pos_,">>>" , token.tag_,">>>" ,spacy.explain(token.tag_))
# Out:
# " >>> PUNCT >>> `` >>> opening quotation mark
# Hey >>> INTJ >>> UH >>> interjection
# , >>> PUNCT >>> , >>> punctuation mark, comma
# my >>> PRON >>> PRP$ >>> pronoun, possessive
# name >>> NOUN >>> NN >>> noun, singular or mass
# is >>> AUX >>> VBZ >>> verb, 3rd person singular present
# Shubham >>> PROPN >>> NNP >>> noun, proper singular
# , >>> PUNCT >>> , >>> punctuation mark, comma
# I >>> PRON >>> PRP >>> pronoun, personal
# am >>> AUX >>> VBP >>> verb, non-3rd person singular present
# a >>> DET >>> DT >>> determiner
# Data >>> PROPN >>> NNP >>> noun, proper singular
# Scientist >>> PROPN >>> NNP >>> noun, proper singular
# working >>> VERB >>> VBG >>> verb, gerund or present participle
# for >>> ADP >>> IN >>> conjunction, subordinating or preposition
# Pfizer >>> PROPN >>> NNP >>> noun, proper singular
# . >>> PUNCT >>> . >>> punctuation mark, sentence closer
# I >>> PRON >>> PRP >>> pronoun, personal
# am >>> AUX >>> VBP >>> verb, non-3rd person singular present
# proficient >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# in >>> ADP >>> IN >>> conjunction, subordinating or preposition
# Advanced >>> PROPN >>> NNP >>> noun, proper singular
# Python >>> PROPN >>> NNP >>> noun, proper singular
# , >>> PUNCT >>> , >>> punctuation mark, comma
# Advanced >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# R >>> NOUN >>> NN >>> noun, singular or mass
# , >>> PUNCT >>> , >>> punctuation mark, comma
# Advanced >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# EXCEL >>> PROPN >>> NNP >>> noun, proper singular
# and >>> CCONJ >>> CC >>> conjunction, coordinating
# Advanced >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# SQL >>> PROPN >>> NNP >>> noun, proper singular
# . >>> PUNCT >>> . >>> punctuation mark, sentence closer
# I >>> PRON >>> PRP >>> pronoun, personal
# am >>> AUX >>> VBP >>> verb, non-3rd person singular present
# also >>> ADV >>> RB >>> adverb
# an >>> DET >>> DT >>> determiner
# expert >>> NOUN >>> NN >>> noun, singular or mass
# in >>> ADP >>> IN >>> conjunction, subordinating or preposition
# Machine >>> PROPN >>> NNP >>> noun, proper singular
# Learning >>> PROPN >>> NNP >>> noun, proper singular
# Algorithms >>> PROPN >>> NNP >>> noun, proper singular
# , >>> PUNCT >>> , >>> punctuation mark, comma
# Natural >>> PROPN >>> NNP >>> noun, proper singular
# Language >>> PROPN >>> NNP >>> noun, proper singular
# Processing >>> PROPN >>> NNP >>> noun, proper singular
# , >>> PUNCT >>> , >>> punctuation mark, comma
# Deep >>> PROPN >>> NNP >>> noun, proper singular
# Learning >>> PROPN >>> NNP >>> noun, proper singular
# , >>> PUNCT >>> , >>> punctuation mark, comma
# and >>> CCONJ >>> CC >>> conjunction, coordinating
# Big >>> PROPN >>> NNP >>> noun, proper singular
# Data >>> PROPN >>> NNP >>> noun, proper singular
# . >>> PUNCT >>> . >>> punctuation mark, sentence closer
# I >>> PRON >>> PRP >>> pronoun, personal
# am >>> AUX >>> VBP >>> verb, non-3rd person singular present
# also >>> ADV >>> RB >>> adverb
# proficient >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# in >>> ADP >>> IN >>> conjunction, subordinating or preposition
# Amazon >>> PROPN >>> NNP >>> noun, proper singular
# AWS >>> PROPN >>> NNP >>> noun, proper singular
# and >>> CCONJ >>> CC >>> conjunction, coordinating
# data >>> NOUN >>> NNS >>> noun, plural
# Visualisation >>> PROPN >>> NNP >>> noun, proper singular
# Techniques >>> PROPN >>> NNPS >>> noun, proper plural
# like >>> ADP >>> IN >>> conjunction, subordinating or preposition
# Power >>> PROPN >>> NNP >>> noun, proper singular
# BI >>> PROPN >>> NNP >>> noun, proper singular
# and >>> CCONJ >>> CC >>> conjunction, coordinating
# Tableau >>> PROPN >>> NNP >>> noun, proper singular
# . >>> PUNCT >>> . >>> punctuation mark, sentence closer
# I >>> PRON >>> PRP >>> pronoun, personal
# am >>> AUX >>> VBP >>> verb, non-3rd person singular present
# an >>> DET >>> DT >>> determiner
# asset >>> NOUN >>> NN >>> noun, singular or mass
# to >>> ADP >>> IN >>> conjunction, subordinating or preposition
# my >>> PRON >>> PRP$ >>> pronoun, possessive
# organisation >>> NOUN >>> NN >>> noun, singular or mass
# . >>> PUNCT >>> . >>> punctuation mark, sentence closer
# I >>> PRON >>> PRP >>> pronoun, personal
# am >>> AUX >>> VBP >>> verb, non-3rd person singular present
# also >>> ADV >>> RB >>> adverb
# an >>> DET >>> DT >>> determiner
# expert >>> NOUN >>> NN >>> noun, singular or mass
# in >>> ADP >>> IN >>> conjunction, subordinating or preposition
# modelling >>> VERB >>> VBG >>> verb, gerund or present participle
# complex >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# optimization >>> NOUN >>> NN >>> noun, singular or mass
# problems >>> NOUN >>> NNS >>> noun, plural
# and >>> CCONJ >>> CC >>> conjunction, coordinating
# have >>> VERB >>> VBP >>> verb, non-3rd person singular present
# a >>> DET >>> DT >>> determiner
# strong >>> ADJ >>> JJ >>> adjective (English), other noun-modifier (Chinese)
# hold >>> NOUN >>> NN >>> noun, singular or mass
# in >>> ADP >>> IN >>> conjunction, subordinating or preposition
# the >>> DET >>> DT >>> determiner
# Operations >>> PROPN >>> NNP >>> noun, proper singular
# Reserach >>> PROPN >>> NNP >>> noun, proper singular
# Domain >>> PROPN >>> NNP >>> noun, proper singular
# . >>> PUNCT >>> . >>> punctuation mark, sentence closer
# " >>> PUNCT >>> '' >>> closing quotation mark
#
#  >>> SPACE >>> _SP >>> whitespace

# %%
doc.count_by(spacy.attrs.POS)
# Out:
# {97: 15,
#  91: 1,
#  95: 8,
#  92: 10,
#  87: 7,
#  96: 28,
#  90: 6,
#  100: 3,
#  85: 8,
#  84: 7,
#  89: 5,
#  86: 3,
#  103: 1}

# %%
nlp.vocab[97].text
# Out:
# 'PUNCT'

# %%
for i,j in doc.count_by(spacy.attrs.POS).items():
    print(i, nlp.vocab[i].text, " count " , j)
# Out:
# 97 PUNCT  count  15
# 91 INTJ  count  1
# 95 PRON  count  8
# 92 NOUN  count  10
# 87 AUX  count  7
# 96 PROPN  count  28
# 90 DET  count  6
# 100 VERB  count  3
# 85 ADP  count  8
# 84 ADJ  count  7
# 89 CCONJ  count  5
# 86 ADV  count  3
# 103 SPACE  count  1

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['Hey'].is_stop
# Out:
# False

# %%
for i,j in doc.count_by(spacy.attrs.TAG).items():
    print(i, nlp.vocab[i].text, " count " , j)
# Out:
# 4969857429396651903 ``  count  1
# 3252815442139690129 UH  count  1
# 2593208677638477497 ,  count  7
# 4062917326063685704 PRP$  count  2
# 15308085513773655218 NN  count  8
# 13927759927860985106 VBZ  count  1
# 15794550382381185553 NNP  count  27
# 13656873538139661788 PRP  count  6
# 9188597074677201817 VBP  count  7
# 15267657372422890137 DT  count  6
# 1534113631682161808 VBG  count  2
# 1292078113972184607 IN  count  8
# 12646065887601541794 .  count  6
# 10554686591937588953 JJ  count  7
# 17571114184892886314 CC  count  5
# 164681854541413346 RB  count  3
# 783433942507015291 NNS  count  2
# 11233576250605462493 NNPS  count  1
# 14143520107006108953 ''  count  1
# 6893682062797376370 _SP  count  1

# %%
from spacy import displacy

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cd7a620324a746ec967332844a8bd472-0" class="displacy" width="15450" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Hey,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">name</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Shubham,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Scientist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Pfizer.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">proficient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Python,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">R,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">EXCEL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">SQL.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="

# %%
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="55c7a00e671749df9e73dee131cced16-0" class="displacy" width="15450" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Hey,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">name</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Shubham,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Scientist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Pfizer.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">proficient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Python,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">R,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">EXCEL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Advanced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">SQL.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;Hey, my name is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shubham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , I am a Data Scientist working for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pfizer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . I am proficient in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Advanced Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Advanced R, Advanced EXCEL and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Advanced SQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . I am also an expert in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning Algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Natural Language Processing,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deep Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Big Data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . I am also proficient in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and data
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visualisation Techniques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Power BI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tableau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . I am an asset to my organisation. I am also an expert in modelling complex optimization problems and have a strong hold in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Operations Reserach Domain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# .&quot;</br></div></span>
